# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import seaborn as sb
 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler

import pickle

from gensim.models import FastText

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (114000, 21)

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.isnull().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['track_id'].nunique(), df.shape
# Out:
# (89740, (113999, 20))

# %%
df[df.duplicated(subset = df.columns.difference(['album_name','track_id']))]
# Out:
#                       track_id                                     artists  \
# 28      5QAMZTM5cmLg3fHX9ZbTZi                                  Jason Mraz
# 29      2qESE1ZeWly7I3YjyTXmXh                                  Jason Mraz
# 30      3EQV1ZHtHvq9OnVRYIdbg3                                  Jason Mraz
# 31      3ax0rfGb7exLtl02LL08U9                                  Jason Mraz
# 34      0xbMRcMFqxJq1Wa7tvWPtn                    Brandi Carlile;Sam Smith
# ...                        ...                                         ...
# 113041  5izpR8PlJCjgJexf7JkMa9                                   Kari Jobe
# 113345  5WaioelSGekDk3UNQy8zaw                                 Matt Redman
# 113644  5uXMiTPXw21xFvyeyqxyIw  Hillsong Worship;Benjamin William Hastings
# 113786  37Ms9rdo26omDpCINsHhui            Chris Tomlin;Steffany Gretzinger
# 113882  7lYdF3SC4SCJPg5kROvXWx                       Bryan & Katie Torwalt
#
#                                               album_name  \
# 28                                        Christmas Time
# 29                                Perfect Christmas Hits
# 30                                       Merry Christmas
# 31                        Christmas Music - Holiday Hits
# 34                    Feeling Good - Adult Pop Favorites
# ...                                                  ...
# 113041                                   Sad Covers 2022
# 113345  Sing Like Never Before: The Essential Collection
# 113644                           That's The Power (Live)
# 113786                          O Lord, You're Beautiful
# 113882                I've Got Good News (Live) [Deluxe]
#
#                                                track_name  popularity  \
# 28                                      Winter Wonderland           0
# 29                                      Winter Wonderland           0
# 30                                      Winter Wonderland           0
# 31                                      Winter Wonderland           0
# 34                                           Party of One           0
# ...                                                   ...         ...
# 113041  In The Name Of Love - Recorded At Spotify Stud...           2
# 113345                            Our God - New Recording          34
# 113644                            That's The Power - Live          43
# 113786  O Lord, You’re Beautiful (with Steffany Gretzi...          43
# 113882                                   Good News - Live          23
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 28           131760     False         0.620   0.309    5    -9.209     1
# 29           131760     False         0.620   0.309    5    -9.209     1
# 30           131760     False         0.620   0.309    5    -9.209     1
# 31           131760     False         0.620   0.309    5    -9.209     1
# 34           259558     False         0.296   0.206    0   -11.799     1
# ...             ...       ...           ...     ...  ...       ...   ...
# 113041       205738     False         0.675   0.375    6    -8.985     1
# 113345       265373     False         0.487   0.895   11    -5.061     1
# 113644       274533     False         0.454   0.635   10    -8.286     1
# 113786       235599     False         0.406   0.121    5   -11.650     1
# 113882       266632     False         0.473   0.474    6    -9.175     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 28           0.0495      0.788000          0.000000    0.1460   0.6640
# 29           0.0495      0.788000          0.000000    0.1460   0.6640
# 30           0.0495      0.788000          0.000000    0.1460   0.6640
# 31           0.0495      0.788000          0.000000    0.1460   0.6640
# 34           0.0412      0.782000          0.000225    0.0959   0.2020
# ...             ...           ...               ...       ...      ...
# 113041       0.0452      0.542000          0.000003    0.0951   0.1870
# 113345       0.0413      0.000183          0.000000    0.3590   0.3840
# 113644       0.0331      0.010300          0.000000    0.2330   0.0931
# 113786       0.0373      0.806000          0.000000    0.1150   0.3870
# 113882       0.0558      0.395000          0.000000    0.1630   0.2510
#
#           tempo  time_signature  track_genre
# 28      145.363               4     acoustic
# 29      145.363               4     acoustic
# 30      145.363               4     acoustic
# 31      145.363               4     acoustic
# 34      165.400               4     acoustic
# ...         ...             ...          ...
# 113041  134.023               4  world-music
# 113345  105.021               4  world-music
# 113644  148.169               4  world-music
# 113786  118.071               4  world-music
# 113882  140.746               4  world-music
#
# [7051 rows x 20 columns]

# %%
df.drop_duplicates(subset = ['track_id'], keep = 'first', inplace=True)
df.drop_duplicates(subset = df.columns.difference(['album_name','track_id']), keep = 'first', inplace=True)

# %%
df = df.sort_values(by=['popularity'], ascending=False).reset_index(drop=True)

# %%
df
# Out:
#                      track_id                  artists  \
# 0      3nqQXoyQOWXiESFLlDF1hG     Sam Smith;Kim Petras
# 1      2tTmW7RDtMQtBk7m2rYeSw         Bizarrap;Quevedo
# 2      5ww2BF9slyYgNOk37BlC4u            Manuel Turizo
# 3      4uUG5RXrOk84mYEfFvj3cK  David Guetta;Bebe Rexha
# 4      1IHWl5LamUGEuP4ozKQSXZ                Bad Bunny
# ...                       ...                      ...
# 86090  1VCZcKzxff1EmN8eNcFVZy             The Supremes
# 86091  1G2foJrzF9F4PcLx1bpSmu             The Supremes
# 86092  03Gkwcxnqw20G27uEvIxSM             The Supremes
# 86093  4t8FOtt2xPRrxlhiqW1sKz             The Supremes
# 86094  5oiqs4M00v4hVOwywRM6vY                 Zoe Wees
#
#                                   album_name  \
# 0                  Unholy (feat. Kim Petras)
# 1      Quevedo: Bzrp Music Sessions, Vol. 52
# 2                                 La Bachata
# 3                            I'm Good (Blue)
# 4                           Un Verano Sin Ti
# ...                                      ...
# 86090                         Best R&B Tunes
# 86091                    60s Christmas Party
# 86092                   A Very 60s Christmas
# 86093                Christmas Soul Classics
# 86094                      Autumn Vibes 2022
#
#                                               track_name  popularity  \
# 0                              Unholy (feat. Kim Petras)         100
# 1                  Quevedo: Bzrp Music Sessions, Vol. 52          99
# 2                                             La Bachata          98
# 3                                        I'm Good (Blue)          98
# 4                                       Tití Me Preguntó          97
# ...                                                  ...         ...
# 86090  If My Friends Could See Me Now/Nothing Can Sto...           0
# 86091                        Little Bright Star - Stereo           0
# 86092                              Born Of Mary - Stereo           0
# 86093                 Children's Christmas Song - Stereo           0
# 86094                                       Daddy's Eyes           0
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 0           156943     False         0.714   0.472    2    -7.375     1
# 1           198937     False         0.621   0.782    2    -5.548     1
# 2           162637     False         0.835   0.679    7    -5.329     0
# 3           175238      True         0.561   0.965    7    -3.673     0
# 4           243716     False         0.650   0.715    5    -5.198     0
# ...            ...       ...           ...     ...  ...       ...   ...
# 86090       198965     False         0.300   0.579    0    -9.583     0
# 86091       146000     False         0.711   0.774    3    -6.769     1
# 86092       168493     False         0.445   0.364    8   -11.775     1
# 86093       170506     False         0.674   0.666   10    -9.749     1
# 86094       182969     False         0.567   0.651    2    -4.693     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0864       0.01300          0.000005     0.266    0.238
# 1           0.0440       0.01250          0.033000     0.230    0.550
# 2           0.0364       0.58300          0.000002     0.218    0.850
# 3           0.0343       0.00383          0.000007     0.371    0.304
# 4           0.2530       0.09930          0.000291     0.126    0.187
# ...            ...           ...               ...       ...      ...
# 86090       0.0391       0.54000          0.000073     0.981    0.707
# 86091       0.0564       0.54900          0.000000     0.103    0.553
# 86092       0.0263       0.68100          0.000000     0.331    0.127
# 86093       0.0381       0.39200          0.000000     0.231    0.734
# 86094       0.0405       0.44700          0.000000     0.590    0.189
#
#          tempo  time_signature track_genre
# 0      131.121               4       dance
# 1      128.033               4     hip-hop
# 2      124.980               4       latin
# 3      128.040               4       dance
# 4      106.672               4       latin
# ...        ...             ...         ...
# 86090   77.150               4       disco
# 86091  115.007               4       disco
# 86092  100.755               3       disco
# 86093  115.868               4       disco
# 86094  123.903               4      german
#
# [86095 rows x 20 columns]

# %%
df['artists'] = df['artists'].apply(lambda x:x.replace(";"," "))

# %%
df['tags'] = df['artists'] + " " + df['album_name'] + " " + df['track_name'] + " " + df['track_genre']

# %%
def data_text_preprocess(total_text, ind, col):
    # Remove int values from text data as that might not be important
    if type(total_text) is not int:
        string = ""
        # replacing all special char with space
        total_text = re.sub(r'[^a-zA-Z0-9\n]', ' ', str(total_text))
        # replacing multiple spaces with single space
        total_text = re.sub(r'\s+', ' ', str(total_text))
        # bring whole text to same lower-case scale
        total_text = total_text.lower()
        
        for word in total_text.split():
            string += word + " "
        
        df[col][ind] = string

# %%
for index, row in df.iterrows():
    if type(row['tags']) is str:
        data_text_preprocess(row['tags'], index, 'tags')

# %%
df.drop(['artists', 'album_name', 'track_genre'], axis=1, inplace = True)

# %%
df = df.head(10000)

# %%
df['processed_tags'] = df['tags'].apply(lambda x : x.split())
fasttext_model = FastText(sentences=df['processed_tags'], vector_size=100, window=5, min_count=1, sg=1)

# %%
def sentence_to_vector(sentence, model):
    words = sentence
    word_vectors = [model.wv[word] for word in words if word in model.wv]
    return np.mean(word_vectors, axis=0)

# %%
def combined_vector(df, model):
    word_to_vec = sentence_to_vector(df['processed_tags'], fasttext_model) 
    
    numerical_features = np.array([df['popularity'], df['duration_ms'], df['danceability'], df['loudness'], df['energy'], df['speechiness'], df['instrumentalness'], df['liveness'], df['valence'], df['tempo']])
    
    scaler = StandardScaler()
    normalized_numerical_features = scaler.fit_transform(numerical_features.reshape(-1, 1))

    normalized_numerical_features = normalized_numerical_features.flatten()

    final_vector = np.concatenate([word_to_vec, normalized_numerical_features])

    return final_vector

# %%
df['vectors'] = df.apply(lambda x: combined_vector(x, fasttext_model), axis=1)

# %%
vector_matrix = np.vstack(df['vectors'].values)
similar = cosine_similarity(vector_matrix)

# %%
def recommender(track_name):
    idx = df[df['track_name'] == track_name].index[0]
    distances = sorted(list(enumerate(similar[idx])), reverse = True, key = lambda x:x[1])
    track_list=[]
    for i in distances[1:6]:
        track_list.append(df.iloc[i[0]].track_name)
    return track_list

# %%
 for i in recommender("Shape of You"):
     print(i)
# Out:
# Perfect
# Pain
# Take My Breath Away - Love Theme from "Top Gun"
# Rise Above This
# Send Me An Angel

# %%
pickle.dump(df, open('music.pkl', 'wb'))
pickle.dump(similar, open('similarity.pkl', 'wb'))
